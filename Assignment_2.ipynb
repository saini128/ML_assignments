# %% [markdown]
# <a href="https://colab.research.google.com/github/saini128/ML_assignments/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.DataFrame()

# %%
df['First Name']=['Hushraj','Parneet','Mankirat','Yugan','Yuvraj','Birendeep','Priyanshu','Moksh','Archita','Prathamjyot']
df['Last Name']=['Singh','Kaur','Singh','Dhar','Singh','Singh','Sharma','Sharma','Jain','Singh']
df['Age']=[20,19,21,20,18,20,17,19,22,21]
df['Gender']=['Male','Female','Male','Male','Male','Male','Male','Male','Female','Male']
df
# Out:
#     First Name Last Name  Age  Gender
# 0      Hushraj     Singh   20    Male
# 1      Parneet      Kaur   19  Female
# 2     Mankirat     Singh   21    Male
# 3        Yugan      Dhar   20    Male
# 4       Yuvraj     Singh   18    Male
# 5    Birendeep     Singh   20    Male
# 6    Priyanshu    Sharma   17    Male
# 7        Moksh    Sharma   19    Male
# 8      Archita      Jain   22  Female
# 9  Prathamjyot     Singh   21    Male

# %%
#navigating df
print(df.iloc[3])
print('\nindex to index\n')
print(df.iloc[1:4])
print('\nall\n')
print(df.iloc[:])
print('\nindex to index union index to index\n')
print(df.iloc[1:4, 5:8])
# Out:
# First Name    Yugan
# Last Name      Dhar
# Age              20
# Gender         Male
# Name: 3, dtype: object
#
# index to index
#
#   First Name Last Name  Age  Gender
# 1    Parneet      Kaur   19  Female
# 2   Mankirat     Singh   21    Male
# 3      Yugan      Dhar   20    Male
#
# all
#
#     First Name Last Name  Age  Gender
# 0      Hushraj     Singh   20    Male
# 1      Parneet      Kaur   19  Female
# 2     Mankirat     Singh   21    Male
# 3        Yugan      Dhar   20    Male
# 4       Yuvraj     Singh   18    Male
# 5    Birendeep     Singh   20    Male
# 6    Priyanshu    Sharma   17    Male
# 7        Moksh    Sharma   19    Male
# 8      Archita      Jain   22  Female
# 9  Prathamjyot     Singh   21    Male
#
# index to index union index to index
#
# Empty DataFrame
# Columns: []
# Index: [1, 2, 3]

# %%
df.iloc[1:4, 1:3]
# Out:
#   Last Name  Age
# 1      Kaur   19
# 2     Singh   21
# 3      Dhar   20

# %%
df[df['Gender']=='Female']
# Out:
#   First Name Last Name  Age  Gender
# 1    Parneet      Kaur   19  Female
# 8    Archita      Jain   22  Female

# %%
df[df['Age']>=20]
# Out:
#     First Name Last Name  Age  Gender
# 0      Hushraj     Singh   20    Male
# 2     Mankirat     Singh   21    Male
# 3        Yugan      Dhar   20    Male
# 5    Birendeep     Singh   20    Male
# 8      Archita      Jain   22  Female
# 9  Prathamjyot     Singh   21    Male

# %%
 print(df.groupby('Age').sum())
# Out:
#                 First Name       Last Name        Gender
# Age
# 17               Priyanshu          Sharma          Male
# 18                  Yuvraj           Singh          Male
# 19            ParneetMoksh      KaurSharma    FemaleMale
# 20   HushrajYuganBirendeep  SinghDharSingh  MaleMaleMale
# 21     MankiratPrathamjyot      SinghSingh      MaleMale
# 22                 Archita            Jain        Female

# %%
for name in df['First Name']:
  print(name.upper())
# Out:
# HUSHRAJ
# PARNEET
# MANKIRAT
# YUGAN
# YUVRAJ
# BIRENDEEP
# PRIYANSHU
# MOKSH
# ARCHITA
# PRATHAMJYOT

# %%
import numpy as np

# %%
df['Age'].apply(np.sqrt)
# Out:
# 0    4.472136
# 1    4.358899
# 2    4.582576
# 3    4.472136
# 4    4.242641
# 5    4.472136
# 6    4.123106
# 7    4.358899
# 8    4.690416
# 9    4.582576
# Name: Age, dtype: float64

# %%
print(pd.isna(df))
